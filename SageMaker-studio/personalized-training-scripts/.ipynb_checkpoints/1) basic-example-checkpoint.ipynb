# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role

# %%
hyperparameters = {"epochs": "2", "batch-size": "32", "test-batch-size": "100", "lr": "0.001"}

estimator = PyTorch(
    entry_point="scripts/pytorch_cifar.py",
    base_job_name="sagemaker-script-mode",
    role=get_execution_role(),
    instance_count=1,
    instance_type="ml.m5.large",
    hyperparameters=hyperparameters,
    framework_version="1.8",
    py_version="py36",
)

# %%
estimator.fit(wait=True)
# Out:
# 2021-11-30 21:50:24 Starting - Starting the training job...
# 2021-11-30 21:50:48 Starting - Launching requested ML instancesProfilerReport-1638309024: InProgress
# ......
# 2021-11-30 21:51:48 Starting - Preparing the instances for training.........
# 2021-11-30 21:53:21 Downloading - Downloading input data
# 2021-11-30 21:53:21 Training - Downloading the training image.....
# 2021-11-30 21:54:27 Uploading - Uploading generated training modelbash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-11-30 21:54:09,910 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-11-30 21:54:09,912 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-30 21:54:09,920 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-11-30 21:54:16,173 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-11-30 21:54:16,518 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-30 21:54:16,528 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-30 21:54:16,538 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-30 21:54:16,547 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "test-batch-size": "100",
#         "lr": "0.001",
#         "epochs": "2"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-script-mode-2021-11-30-21-50-24-089",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-678049007427/sagemaker-script-mode-2021-11-30-21-50-24-089/source/sourcedir.tar.gz",
#     "module_name": "pytorch_cifar",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_cifar.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"}
# SM_USER_ENTRY_POINT=pytorch_cifar.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_cifar
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-678049007427/sagemaker-script-mode-2021-11-30-21-50-24-089/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-script-mode-2021-11-30-21-50-24-089","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-678049007427/sagemaker-script-mode-2021-11-30-21-50-24-089/source/sourcedir.tar.gz","module_name":"pytorch_cifar","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"pytorch_cifar.py"}
# SM_USER_ARGS=["--batch-size","32","--epochs","2","--lr","0.001","--test-batch-size","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH-SIZE=32
# SM_HP_TEST-BATCH-SIZE=100
# SM_HP_LR=0.001
# SM_HP_EPOCHS=2
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.001 --test-batch-size 100
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# Extracting ../data/cifar-10-python.tar.gz to ../data
# [2021-11-30 21:54:23.007 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-11-30 21:54:23.380 algo-1:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2021-11-30 21:54:23.380 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-11-30 21:54:23.381 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-11-30 21:54:23.381 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2021-11-30 21:54:23.381 algo-1:27 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2021-11-30 21:54:23.397 algo-1:27 INFO hook.py:591] name:conv1.weight count_params:288
# [2021-11-30 21:54:23.397 algo-1:27 INFO hook.py:591] name:conv1.bias count_params:32
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:conv2.weight count_params:18432
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:conv2.bias count_params:64
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:fc1.weight count_params:1179648
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:fc1.bias count_params:128
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:fc2.weight count_params:1280
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:591] name:fc2.bias count_params:10
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:593] Total Trainable Params: 1199882
# [2021-11-30 21:54:23.398 algo-1:27 INFO hook.py:425] Monitoring the collections: losses
# [2021-11-30 21:54:23.402 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  1%|          | 902144/170498071 [00:00<00:21, 7806002.81it/s]#015  5%|▍         | 8307712/170498071 [00:00<00:03, 44084800.26it/s]#015 10%|▉         | 16996352/170498071 [00:00<00:02, 58953491.54it/s]#015 16%|█▌        | 27133952/170498071 [00:00<00:01, 74666426.76it/s]#015 22%|██▏       | 37180416/170498071 [00:00<00:01, 83593648.76it/s]#015 28%|██▊       | 48158720/170498071 [00:00<00:01, 92256647.04it/s]#015 35%|███▌      | 59850752/170498071 [00:00<00:01, 100165048.50it/s]#015 42%|████▏     | 71578624/170498071 [00:00<00:00, 105543089.88it/s]#015 49%|████▉     | 83156992/170498071 [00:00<00:00, 108716148.03it/s]#015 56%|█████▌    | 95044608/170498071 [00:01<00:00, 111820389.93it/s]#015 63%|██████▎   | 106775552/170498071 [00:01<00:00, 113493066.87it/s]#015 70%|██████▉   | 118507520/170498071 [00:01<00:00, 114649240.26it/s]#015 76%|███████▋  | 130253824/170498071 [00:01<00:00, 115484307.20it/s]#015 83%|████████▎ | 141815808/170498071 [00:01<00:00, 114858591.62it/s]#015 90%|█████████ | 153549824/170498071 [00:01<00:00, 115602063.84it/s]#015 97%|█████████▋| 165282816/170498071 [00:01<00:00, 116093249.11it/s]#015170499072it [00:01, 101501511.35it/s]
# Traceback (most recent call last):
#   File "pytorch_cifar.py", line 124, in <module>
#     main()
#   File "pytorch_cifar.py", line 117, in main
#     train(model, train_loader, optimizer, epoch)
#   File "pytorch_cifar.py", line 37, in train
#     output = model(data)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "pytorch_cifar.py", line 19, in forward
#     x = self.conv1(x)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Given groups=1, weight of size [32, 1, 3, 3], expected input[32, 3, 32, 32] to have 1 channels, but got 3 channels instead
# 2021-11-30 21:54:23,569 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.001 --test-batch-size 100"
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  1%|          | 902144/170498071 [00:00<00:21, 7806002.81it/s]#015  5%|â         | 8307712/170498071 [00:00<00:03, 44084800.26it/s]#015 10%|â         | 16996352/170498071 [00:00<00:02, 58953491.54it/s]#015 16%|ââ        | 27133952/170498071 [00:00<00:01, 74666426.76it/s]#015 22%|âââ       | 37180416/170498071 [00:00<00:01, 83593648.76it/s]#015 28%|âââ       | 48158720/170498071 [00:00<00:01, 92256647.04it/s]#015 35%|ââââ      | 59850752/170498071 [00:00<00:01, 100165048.50it/s]#015 42%|âââââ     | 71578624/170498071 [00:00<00:00, 105543089.88it/s]#015 49%|âââââ     | 83156992/170498071 [00:00<00:00, 108716148.03it/s]#015 56%|ââââââ    | 95044608/170498071 [00:01<00:00, 111820389.93it/s]#015 63%|âââââââ   | 106775552/170498071 [00:01<00:00, 113493066.87it/s]#015 70%|âââââââ   | 118507520/170498071 [00:01<00:00, 114649240.26it/s]#015 76%|ââââââââ  | 130253824/170498071 [00:01<00:00, 115484307.20it/s]#015 83%|âââââââââ | 141815808/170498071 [00:01<00:00, 114858591.62it/s]#015 90%|âââââââââ | 153549824/170498071 [00:01<00:00, 115602063.84it/s]#015 97%|ââââââââââ| 165282816/170498071 [00:01<00:00, 116093249.11it/s]#015170499072it [00:01, 101501511.35it/s]
# Traceback (most recent call last):
#   File "pytorch_cifar.py", line 124, in <module>
#     main()
#   File "pytorch_cifar.py", line 117, in main
#     train(model, train_loader, optimizer, epoch)
#   File "pytorch_cifar.py", line 37, in train
#     output = model(data)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "pytorch_cifar.py", line 19, in forward
#     x = self.conv1(x)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py", line 918, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 399, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/opt/conda/lib/python3.6/site-packages/torch/nn/modules/conv.py", line 396, in _conv_forward
#     self.padding, self.dilation, self.groups)
# RuntimeError: Given groups=1, weight of size [32, 1, 3, 3], expected input[32, 3, 32, 32] to have 1 channels, but got 3 channels instead
#
# 2021-11-30 21:54:51 Failed - Training job failed
# ProfilerReport-1638309024: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-16-0d78e911798a> in <module>
# ----> 1 estimator.fit(wait=True)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     690         self.jobs.append(self.latest_training_job)
#     691         if wait:
# --> 692             self.latest_training_job.wait(logs=logs)
#     693
#     694     def _compilation_job_name(self):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1650         # If logs are requested, call logs_for_jobs.
#    1651         if logs != "None":
# -> 1652             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1653         else:
#    1654             self.sagemaker_session.wait_for_job(self.job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3776
#    3777         if wait:
# -> 3778             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3779             if dot:
#    3780                 print()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3333                 ),
#    3334                 allowed_statuses=["Completed", "Stopped"],
# -> 3335                 actual_status=status,
#    3336             )
#    3337
#
# UnexpectedStatusException: Error for Training job sagemaker-script-mode-2021-11-30-21-50-24-089: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.001 --test-batch-size 100"
#  70%|âââ

# %%
estimator.base_job_name

# %%
estimator.hyperparameters()
